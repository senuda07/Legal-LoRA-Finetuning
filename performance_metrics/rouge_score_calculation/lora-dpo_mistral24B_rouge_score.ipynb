# %%
pip install rouge-score pandas matplotlib seaborn
# Out:
# Requirement already satisfied: rouge-score in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: pandas in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: seaborn in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: absl-py in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from rouge-score) (2.4.0)
# Requirement already satisfied: nltk in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from rouge-score) (3.9.2)
# Requirement already satisfied: numpy in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from rouge-score) (2.2.5)
# Requirement already satisfied: six>=1.14.0 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: click in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from nltk->rouge-score) (8.3.0)
# Requirement already satisfied: joblib in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from nltk->rouge-score) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from nltk->rouge-score) (2025.11.3)
# Requirement already satisfied: tqdm in /Users/senudaliyanage/miniconda3/envs/IRP/lib/python3.10/site-packages (from nltk->rouge-score) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
from rouge_score import rouge_scorer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
reference_dir = "/Users/senudaliyanage/Downloads/IIT/Final Year Project/Legal Document Summarization/results/openai_results/openai_summaries_test_merged"
model_dir = "/Users/senudaliyanage/Downloads/IIT/Final Year Project/Legal Document Summarization/results/lora-dpo_mistral24B_results/lora-dpo_mistral24B_summaries_test_merged"

# %%
scorer = rouge_scorer.RougeScorer(
    ['rouge1', 'rouge2', 'rougeL'],
    use_stemmer=True
)

# %%
results = []

for file in os.listdir(reference_dir):

    if not file.endswith(".txt"):
        continue
        
    ref_path = os.path.join(reference_dir, file)
    model_path = os.path.join(model_dir, file)

    if not os.path.exists(model_path):
        continue

    with open(ref_path) as f:
        reference = f.read()

    with open(model_path) as f:
        prediction = f.read()

    scores = scorer.score(reference, prediction)

    results.append({
        "document": file,
        "rouge1": scores["rouge1"].fmeasure,
        "rouge2": scores["rouge2"].fmeasure,
        "rougeL": scores["rougeL"].fmeasure
    })

df = pd.DataFrame(results)

df.head()
# Out:
#              document    rouge1    rouge2    rougeL
# 0   2019-08-20-56.txt  0.379310  0.191304  0.250000
# 1  2017-08-08-223.txt  0.336746  0.125428  0.168373
# 2   2015-09-22-78.txt  0.413534  0.166038  0.218045
# 3   2007-02-09-05.txt  0.373438  0.170579  0.189062
# 4   2013-03-08-08.txt  0.590571  0.394015  0.387097

# %%
mean_scores = df[["rouge1","rouge2","rougeL"]].mean()

print("Mean ROUGE scores:")
print(mean_scores)
# Out:
# Mean ROUGE scores:
# rouge1    0.513122
# rouge2    0.258686
# rougeL    0.314605
# dtype: float64

# %%
plt.figure(figsize=(8,6))

sns.boxplot(data=df[["rouge1","rouge2","rougeL"]])

plt.title("ROUGE Score Distribution")
plt.ylabel("Score (0-1)")
plt.show()

# %%
score_cols = ["rouge1", "rouge2", "rougeL"]

Q1 = df[score_cols].quantile(0.25)
Q3 = df[score_cols].quantile(0.75)

IQR = Q3 - Q1

# %%
df_clean = df[~(
    (df[score_cols] < (Q1 - 1.5 * IQR)) |
    (df[score_cols] > (Q3 + 1.5 * IQR))
).any(axis=1)]

# %%
df_clean[score_cols].mean()
# Out:
# rouge1    0.509639
# rouge2    0.249845
# rougeL    0.305672
# dtype: float64

# %%
print("Original docs:", len(df))
print("After outlier removal:", len(df_clean))
# Out:
# Original docs: 438
# After outlier removal: 413
